# %%
{
  "projectName": "DataDrive_Conv",
  "projectOwner": "luisfilipemic",
  "repoType": "github",
  "repoHost": "https://github.com",
  "files": ["README.md"],
  "imageSize": 100,
  "contributors": []
}
