# %% [raw]
# ---
# title: "Relatório iniciação cientifica - Conversor Buck"
# author: "Luiz Felipe Souza de Lima Silva"
# date: "2026-04-19"
# course: "Engenharia Elétrica - UFPA"
# subject: "Conversor Buck"
# output:
#   pdf_document: default
#   html_document: default
# Palvras Chave: ["Buck", "Controle", "Modelagem", "Eletrônica de Potência"]
# ---

# %% [markdown]
# ## 1. Introdução
#
# Este documento tem como objetivo apresentar e demonstrar a modelagem no espaço de estados para o conversor buck.
#
# ---
#
# ## 2. Fundamentação teórica.
#
# A partir da modelagem matemática obtem-se o modelo no espaço de estados.
#
# ---
#
# 1. Definir variáveis de estado.
# 2. Definir o modelo na equação de estados.
# 3. Definição do modelo médio.
#
# ---
