# %% [markdown]
#  Projeto do Controlador
#
# 4.1 Objetivo do Controle
#
# 4.2 Modelo utilizado
#
# 4.3 Formulação matemática
#
# 4.4 Escolha da técnica
#
# 4.5 Desenvolvimento do controlador
#
# 4.6 Sintonia
#
# 4.7 Análise de estabilidade
#
# 4.8 Implementação
#
# 4.9 Resumo do controlador

# %% [markdown]
# ## *Objetivo do controle/ Parametros de projeto.*
#
# 1. Malha Aberta: Análise da Planta (O "Motor")
# 2. o sistema é estável por natureza?
# 3.  velocidade de resposta natural

# %% [markdown]
# ## *Modelo Utilizado:*
#
# COntrole PID.
